# %% [markdown]
# ## WEB SCRAPING – ASSIGNMENT 4

# %% [markdown]
# ### Importing liberary

# %%
import pandas as pd
import numpy as np
import time
import selenium

from selenium import webdriver

from selenium.webdriver.common.keys import Keys
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1.Scrape the details of most viewed videos on YouTube from Wikipedia. Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos You need to find following details: A) Rank B) Name C) Artist D) Upload date E) Views

# %%
Url = 'https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
    
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
driver.get(Url)
time.sleep(5)

# %%
#creating blank list for each feature
Rank=[]
Name=[]
Artist=[]
Upload_date=[]
Views_billions=[]

#fetching values one by one

row1=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[1]")
for i in row1:
    try:
        Rank.append(i.text)
    except:
        Rank.append('-')
        
row2=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[2]")
for i in row2:
    try:
        Name.append(i.text)
    except:
        Name.append('-')
        
        
        
row3=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[3]")
for i in row3:
    try:
        Artist.append(i.text)
    except:
        Artist.append('-')        
        
        
        
row5=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[5]")
for i in row5:
    try:
        Upload_date.append(i.text)
    except:
        Upload_date.append('-') 
        
        
row4=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[4]")
for i in row4:
    try:
         Views_billions.append(i.text)
    except:
         Views_billions.append('-')

# %%
#slicing data for table 1 only
Rank=Rank[0:30]
Name=Name[0:30]
Artist=Artist[0:30]
Upload_date=Upload_date[0:30]
Views_billions=Views_billions[0:30]


#creating df

most_views_video=pd.DataFrame({'Rank':Rank,
'Name':Name,
'Artist':Artist,
'Upload_date':Upload_date,
'Views_billions':Views_billions
    
})


most_views_video
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[5]
# 2    3.                       "Johny Johny Yes Papa"[11]
# 3    4.                               "Shape of You"[12]
# 4    5.                              "See You Again"[14]
# 5    6.                                  "Bath Song"[19]
# 6    7.  "Learning Colors – Colorful Eggs on a Farm"[20]
# 7    8.   "Masha and the Bear – Recipe for Disaster"[21]
# 8    9.                                "Uptown Funk"[22]
# 9   10.                "Phonics Song with Two Words"[23]
# 10  11.                              "Gangnam Style"[24]
# 11  12.                             "Dame Tu Cosita"[29]
# 12  13.                                      "Sugar"[30]
# 13  14.                                      "Sorry"[31]
# 14  15.                                       "Roar"[32]
# ...

# %% [markdown]
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1
# st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
#launching website & click on fixture link
Url = 'https://www.bcci.tv/'
    
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
driver.get(Url)
time.sleep(5)

link=driver.find_element_by_xpath("//li[@class='nav-item ml-0']")

link.click()

# %%
#clicking on more matches button until see all 
try:
    for i in range(5):
        more=driver.find_element_by_xpath("//button[@class='match-btn btn-red d-flex align-items-center justify-content-center mx-auto mt-3']")
        more.click()
        time.sleep(1)
        
    i+=1
except:
    pass

# %%
#create blank list
Match_title=[]
Series=[]
Place=[]
Date=[]
Time=[]

#fetching data one by one
title=driver.find_elements_by_xpath("//div[@class='fix-place ng-binding ng-scope']")
for i in title:
    Match_title.append(i.text.split('-')[0])
    

ser=driver.find_elements_by_xpath("//span[@class='ng-binding']")
for i in ser:
    Series.append(i.text)    
    
    
plc=driver.find_elements_by_xpath("//div[@class='fix-place ng-binding ng-scope']")
for i in plc:
    Place.append(i.text.split('-')[1])
    

dat=driver.find_elements_by_xpath("//div[@class='match-card-left match-schedule']/h5")
for i in dat:
    Date.append(i.text)

tim=driver.find_elements_by_xpath("//h5[@class='text-right ng-binding']")
for i in tim:
    Time.append(i.text)
    
print(len(Match_title),len(Series),len(Place),len(Date),len(Time))
# Out:
# 20 20 20 20 20

# %%
#creating dataframe
fixtures_cricket=pd.DataFrame({
'Match_title':Match_title,
'Series':Series,
'Place':Place,
'Date':Date,
'Time':Time
})

fixtures_cricket

driver.close()
# Out:
#                                           Match_title  \
# 0                      3rd Test - Newlands, Cape Town
# 1                        1st ODI - Boland Park, Paarl
# 2                        2nd ODI - Boland Park, Paarl
# 3                       3rd ODI - Newlands, Cape Town
# 4          1st ODI - NARENDRA MODI STADIUM, Ahmedabad
# 5            2nd ODI - Sawai Mansingh Stadium, Jaipur
# 6                     3rd ODI - Eden Gardens, Kolkata
# 7                 1st T20 - Barabati Stadium, Cuttack
# 8   2nd T20 - Dr YS Rajasekhara Reddy ACA-VDCA Cri...
# 9   3rd T20 - Greenfield International Stadium, Th...
# 10        1st Test - M Chinnaswamy Stadium, Bengaluru
# 11  2nd Test - Punjab Cricket Association IS Bindr...
# 12  1st T20 - Punjab Cricket Association IS Bindra...
# 13  2nd T20 - Himachal Pradesh Cricket Association...
# 14  3rd T20 - Bharat Ratna Shri Atal Bihari Vajpay...
# 15          1st T20 - MA Chidambaram Stadium, Chennai
# ...

# %% [markdown]
# 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
#launching website & click on exception link
Url = 'https://www.guru99.com/'
    
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
driver.get(Url)
time.sleep(5)

#click on selenium link
link=driver.find_element_by_xpath("/html/body/footer/div/div[1]/div/div/div/div/div/div/section/div/div/div[2]/div/div/div/div/div[2]/div/div/div[2]/div/div[2]/div/div/div[3]/div/div/div[2]/div/div/a/div[2]/h5")

link.click()

time.sleep(8)

#click on exception link
excepetion_link=driver.find_element_by_xpath("//a[@title='Selenium Exception Handling (Common Exceptions List)']")

excepetion_link.click()

time.sleep(8)

#blank lists
exception_name=[]
description=[]

#fetching data one by one
nam=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[1]")
for i in nam:
    exception_name.append(i.text)
    
    
nam2=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[2]")
for i in nam2:
    description.append(i.text) 
    

#creating data frame    
exceptions=pd.DataFrame({'exception_name':exception_name,
                    'description':description
    
})

exceptions

driver.close()
# Out:
#                          exception_name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %%
4.Scrape the details of State-wise GDP of India from statisticstime.com.
Url = http://statisticstimes.com/
You have to find following details:
A) Rank
B) State
C) GSDP
D) GSDP
E) Share
F) GDP($ billion)
Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
Url = 'http://statisticstimes.com/'
    
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
driver.get(Url)

time.sleep(7)
dp=driver.find_value_by_xpath("//button[@class='dropbtn']")
# dp.click()

# %%
dp=driver.find_element_by_xpath("/html/body/div[2]/div[1]/div[2]/div[2]/button")
dp.click()
time.sleep(2)

ind=driver.find_element_by_xpath("//a[@href='economy/india-statistics.php']")
ind.click()
time.sleep(4)

# %%
sta=driver.find_element_by_xpath("//a[@href='india/indian-states-gdp.php']")
sta.click()

# %%
Rank=[]
State=[]
GSDP_19_20=[]
GSDP_18_19=[]
Share=[]
GDP_billion=[]



ranks=driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[1]")
try:
    for i in ranks:
        Rank.append(i.text)
except:
    Rank.append('-')
    

states=driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[2]")
try:
    for i in states:
        State.append(i.text)
except:
    State.append('-')

    
gsdp1=driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[3]")
try:
    for i in gsdp1:
        GSDP_19_20.append(i.text)
except:
    GSDP_19_20.append('-')
    
    
gsdp2=driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[4]")
try:
    for i in gsdp2:
        GSDP_18_19.append(i.text)
except:
    GSDP_18_19.append('-')    
    

shares=driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[5]")
try:
    for i in shares:
        Share.append(i.text)
except:
    Share.append('-')
    
gdp=driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[6]")
try:
    for i in gdp:
        GDP_billion.append(i.text)
except:
    GDP_billion.append('-')
    
    
print(len(Rank),len(State),len(GSDP_19_20),len(GSDP_18_19),len(Share),len(GDP_billion))  

driver.close()
# Out:
# 33 33 33 33 33 33

# %%
GDP_data=pd.DataFrame({
'Rank':Rank,
'State':State,
'GSDP_19_20':GSDP_19_20,
'GSDP_18_19':GSDP_18_19,
'Share':Share,
'GDP_billion':GDP_billion})

GDP_data
# Out:
#    Rank                      State GSDP_19_20 GSDP_18_19   Share GDP_billion
# 0     1                Maharashtra          -  2,632,792  13.94%     399.921
# 1     2                 Tamil Nadu  1,845,853  1,630,208   8.63%     247.629
# 2     3              Uttar Pradesh  1,687,818  1,584,764   8.39%     240.726
# 3     4                    Gujarat          -  1,502,899   7.96%     228.290
# 4     5                  Karnataka  1,631,977  1,493,127   7.91%     226.806
# 5     6                West Bengal  1,253,832  1,089,898   5.77%     165.556
# 6     7                  Rajasthan  1,020,989    942,586   4.99%     143.179
# 7     8             Andhra Pradesh    972,782    862,957   4.57%     131.083
# 8     9                  Telangana    969,604    861,031   4.56%     130.791
# 9    10             Madhya Pradesh    906,672    809,592   4.29%     122.977
# 10   11                     Kerala          -    781,653   4.14%     118.733
# ...

# %% [markdown]
# 5 Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
#
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
Url = 'https://github.com/ '
    
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
driver.get(Url)
time.sleep(4)

lnk=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary")
lnk.click()
time.sleep(4)

trend=driver.find_element_by_xpath("//a[@href='/trending']")
trend.click()

# %%
Repository_title=[]
Repository_description=[]
Contributors_count=[]
Language_Used=[]


title=driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']")

for i in title:
    Repository_title.append(i.text)

#github site stuck so fetch 1 element.

# %%
Repository_title
# Out:
# ['Asabeneh / 30-Days-Of-JavaScript',
#  'Igglybuff / awesome-piracy',
#  '521xueweihan / HelloGitHub',
#  'megadose / holehe',
#  'alibaba / xquic',
#  'TheAlgorithms / Python',
#  'freeCodeCamp / freeCodeCamp',
#  'VGVentures / slide_puzzle',
#  'iluwatar / java-design-patterns',
#  'withshepherd / faker.js',
#  'lynn / hello-wordl',
#  'TheAlgorithms / Java',
#  'sunym1993 / flash-linux0.11-talk',
#  'ibraheemdev / modern-unix',
#  'faridrashidi / kaggle-solutions',
#  'solo-io / bumblebee',
#  'MichMich / MagicMirror',
#  'LaravelDaily / laravel-tips',
#  'BookStackApp / BookStack',
#  'akullpp / awesome-java',
#  'microsoft / PowerToys',
#  'kdn251 / interviews',
#  'ascoders / weekly',
#  'facebookresearch / mae',
#  'JumpCrypto / crypto-reading-list']

# %% [markdown]
# 6.Scrape the details of top 100 songs on billiboard.com.
#
# Url = https:/www.billboard.com/
#
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
Url = 'https:/www.billboard.com/'
    
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
driver.get(Url)
time.sleep(10)

lnk=driver.find_element_by_xpath("//a[@href='/charts/hot-100']")
lnk.click()
time.sleep(4)

# %%
Song_name=[]
Artist_name=[]
Last_week_rank=[]
Peak_rank=[]
Weeks_on_board=[]

#adding title song
songs=driver.find_elements_by_xpath("//h3[@class='c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-245 u-max-width-230@tablet-only u-letter-spacing-0028@tablet']")
for i in songs:
        Song_name.append(i.text)
#adding rest of the song

songs=driver.find_elements_by_xpath("//h3[@class='c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only']")
for i in songs:
        Song_name.append(i.text)
        
        
        
#adding header artist
artist=driver.find_elements_by_xpath("//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet']")
for i in artist:
        Artist_name.append(i.text)
 #adding rest of the artists       
        
artist=driver.find_elements_by_xpath("//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only']")
for i in artist:
        Artist_name.append(i.text)  
        
        
#adding Last week rank
lrank=driver.find_elements_by_xpath("//li[@class='o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max']/span")

for i in lrank:
    Last_week_rank.append(i.text)
Last_week_rank=Last_week_rank[0:201:2]         
        
#Peak Rank
        
Peak_rank=[]
prank=driver.find_elements_by_xpath("//li[@class='o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-hidden@mobile-max']/span")
for i in prank:
    Peak_rank.append(i.text) 
    
    
#adding Weeks_on_board
boards=driver.find_elements_by_xpath("//li[@class='o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max']/span")

for i in boards:
    Weeks_on_board.append(i.text)
Weeks_on_board=Weeks_on_board[1:201:2]
    
print(len(Song_name),len(Artist_name),len(Last_week_rank),len(Peak_rank),len(Weeks_on_board))

#creating dataframe

song_list=pd.DataFrame({'Song_name':Song_name,
                        'Artist_name':Artist_name,
                        'Last_week_rank':Last_week_rank,
                        'Peak_rank':Peak_rank,
                        'Weeks_on_board':Weeks_on_board
                        })

song_list
# Out:
# 100 100 100 100 100
#                        Song_name  \
# 0                     Easy On Me
# 1                           Stay
# 2                     Heat Waves
# 3                        Shivers
# 4      We Don't Talk About Bruno
# ..                           ...
# 95                     Me Or Sum
# 96                 I Love You So
# 97     Bad Man (Smooth Criminal)
# 98  Never Wanted To Be That Girl
# 99           Just About Over You
#
#                                           Artist_name Last_week_rank  \
# 0                                               Adele              2
# 1                       The Kid LAROI & Justin Bieber              6
# 2                                       Glass Animals              7
# 3                                          Ed Sheeran              9
# 4   Carolina Gaitan, Mauro Castillo, Adassa, Rhenz...             50
# ..                                                ...            ...
# ...

# %% [markdown]
# 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
Url = 'https://www.naukri.com/naukri-dot-com-recruiters'
#couldn't find recruites tab on home page adding recruiters url    
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
driver.get(Url)
time.sleep(5)

inputb=driver.find_element_by_xpath("//input[@class='sugInp']")
inputb.clear()
inputb.send_keys('Data science')
time.sleep(4)

driver.find_element_by_id('qsbFormBtn').click()

# %%
#adding blank lists
Name=[]
Designation=[]
Company=[]
Skills_hire_for=[]
Location=[]

#fetching data one by one
nam=driver.find_elements_by_xpath("//span[@class='fl ellipsis']")
try:
    for i in nam:
        Name.append(i.text)
except:
    Name.append('-')
    
des=driver.find_elements_by_xpath("//span[@class='ellipsis clr']")
try:
    for i in des:
        Designation.append(i.text)
except:
    Designation.append('-')
    


com=driver.find_elements_by_xpath("//a[2][@class='ellipsis']")
try:
    for i in com:
        Company.append(i.text)
except:
    Company.append('-')    
    


skills=driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")
try:
    for i in skills:
        Skills_hire_for.append(i.text)
except:
    Skills_hire_for.append('-')
    
    
#    
Location=[]
loc=driver.find_elements_by_xpath("//small[@class='ellipsis']")
try:
    for i in loc:
         Location.append(i.text)
except:
    Location.append('-')

# %%
recruiters=pd.DataFrame({'Name':Name,
                         'Designation':Designation,
                         'Company':Company,
                         'Skills_hire_for':Skills_hire_for
                         })    

recruiters

driver.close()
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Mahesh Babu Channa
# 15                                Sakshi Chhikara
# 16                                   Kapil Devang
# 17                                    Ruchi Dhote
# ...

# %% [raw]
# 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
Url = 'https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/'   
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
driver.get(Url)
time.sleep(5)

# %%
Book_name=[]
Author_name=[]
Volumes_sold=[]
Publisher=[]
Genre=[]

nam=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[2]")
for i in nam:
        Book_name.append(i.text)
        
        
auth=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[3]")
for i in auth:
        Author_name.append(i.text)        
        
        
vol=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[4]")
for i in vol:
        Volumes_sold.append(i.text)        
        
pub=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[5]")
for i in pub:
        Publisher.append(i.text)         
        
        
gen=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[6]")
for i in gen:
        Genre.append(i.text)
        
book_details=pd.DataFrame({'Book_name':Book_name,
'Author_name':Author_name,
'Volumes_sold':Volumes_sold,
'Publisher':Publisher,
'Genre':Genre
    }) 

book_details 

driver.close()
# Out:
#                                             Book_name       Author_name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes_sold        Publisher                        Genre
# ...

# %% [raw]
# 9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
#Launching url
Url = 'https://www.imdb.com/list/ls095964455/'   
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
driver.get(Url)
time.sleep(5)

# %%
#blank lists
Name=[]
Year_span=[]
Genre=[]
Run_time=[]
Ratings=[]
Votes=[]

#fetching data one by one
nam=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")

for i in nam:
    Name.append(i.text)
    
yr=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/span[2]")

for i in yr:
    Year_span.append(i.text)
    
gen=driver.find_elements_by_xpath("//span[@class='genre']")

for i in gen:
    Genre.append(i.text)
    
run=driver.find_elements_by_xpath("//span[@class='runtime']")

for i in run:
    Run_time.append(i.text)
    
    
rat=driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']/span[2]")

for i in rat:
    Ratings.append(i.text)
    

vot=driver.find_elements_by_xpath("//p[@class='text-muted text-small']/span[2]")

for i in vot:
    Votes.append(i.text)
Votes=Votes[1:201:2]    

movies_list=pd.DataFrame({'Name':Name,
'Year_span':Year_span,
'Genre':Genre,
'Run_time':Run_time,
'Ratings':Ratings,
'Votes':Votes
             })


movies_list

driver.close()
# Out:
#                               Name    Year_span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run_time Ratings      Votes
# 0    57 min     9.2  1,930,901
# ...

# %% [raw]
# 10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
#Launching url
Url = 'https://archive.ics.uci.edu/'   
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
driver.get(Url)
time.sleep(5)

lnk=driver.find_element_by_xpath("//a[@href='datasets.php']")
lnk.click()
time.sleep(5)

# %%
#blank lists
Dataset_name=[]
Data_type=[]
Task=[]
Attribute_type=[]
No_of_instances=[]
No_of_attribute=[]
Year=[]

#fetching data one by one
data=driver.find_elements_by_xpath("//p[@class='normal']/b")
for i in data:
    Dataset_name.append(i.text)
    
    
ty=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]/p")
for i in ty:
    Data_type.append(i.text)
Data_type=Data_type[1:623] 

ts=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]/p")
for i in ts:
    Task.append(i.text)
Task=Task[1:623] 

att=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]/p")
for i in att:
    Attribute_type.append(i.text)
Attribute_type=Attribute_type[1:623] 


ins=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]/p")
for i in ins:
    No_of_instances.append(i.text)
No_of_instances=No_of_instances[1:623]

att=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]/p")
for i in att:
    No_of_attribute.append(i.text)
No_of_attribute=No_of_attribute[1:623] 

yr=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]/p")
for i in yr:
    Year.append(i.text)
Year=Year[1:623] 

#creating dataframe
data_sets=pd.DataFrame({
    'Dataset_name':Dataset_name,
'Data_type':Data_type,
'Task':Task,
'Attribute_type':Attribute_type,
'No_of_instances':No_of_instances,
'No_of_attribute':No_of_attribute,
'Year':Year
    
})

    
data_sets
# Out:
#                                           Dataset_name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data_type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...
