# %% [markdown]
# ### WEB SCRAPING-ASSIGNMENT3

# %% [markdown]
# Instructions:
# • All questions are compulsory.
#
# • In each of the questions you have to automate the process. You do not have to click on any button, click
#
# any clickable element, enter keywords in search boxes manually. Each process has to be performed via
# coding.
#
# • Q1 and Q2 are connected questions i.e. after attempting Q1 proceed to Q2. Do not write whole code
# from beginning for Q2.
#
# • You may use any web scraping library and tools.
#
# • The question can be attempted in various ways; the correctness of question depends on the output.
#
# • If you encounter any Null values during scraping, you may replace it by hyphen.

# %% [markdown]
# Delete this cess after project completion:
# 1. Write a python program which searches all the product under a particular product from www.amazon.in.
# The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search
# for guitars.
# 2. In the above question, now scrape the following details of each product listed in first 3 pages of your
# search results and save it in a data frame and csv. In case if any product has less than 3 pages in search
# results then scrape all the products available under that product name. Details to be scraped are: "Brand
# Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and
# “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.
# 3. Write a python program to access the search bar and search button on images.google.com and scrape 10
# images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.
# 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be
# scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# details is missing then replace it by “- “. Save your results in a dataframe and CSV.
# 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google
# maps.
# 6. Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21)
# from trak.in.
# 7. Write a program to scrap all the available details of best gaming laptops from digit.in.
# 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be
# scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.
# 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted
# from any YouTube Video.
# 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in
# “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews,
# overall reviews, privates from price, dorms from price, facilities and property description.

# %% [markdown]
# 1-Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %% [markdown]
# ### Importing necessary library

# %%
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
import numpy as np
from selenium.webdriver.common.keys import Keys
import selenium

from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1-Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
#def amazon_search(keyword):
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
url='https://www.amazon.in/'

# %%
driver.get(url)
time.sleep(5)

search_box=driver.find_element_by_id('twotabsearchtextbox')
search_box.clear()

user_input=input("enter product to search:")

time.sleep(2)
search_box.send_keys(user_input)
btn=driver.find_element_by_id('nav-search-submit-button')
btn.click()
# Out:
# enter product to search:guitar

# %% [markdown]
# 2.In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
#making empty lists to hold required details

Brand_name=[]
Product_name=[]
Price=[]
Return_Exchange=[]
Expected_delivery=[]
Availability=[]
Product_url=[]

#scrapping data one by one

brand=driver.find_elements_by_xpath("//span[@class='a-size-base-plus a-color-base a-text-normal']")
for i in brand:
    if i.text is None:
        Brand_name.append('--')
    else:    
        Brand_name.append(i.text.split(' ')[0])  

time.sleep(2)        
Product=driver.find_elements_by_xpath("//span[@class='a-size-base-plus a-color-base a-text-normal']")
for i in brand:
    if i.text is None:
        Product_name.append('--')
    else:    
        Product_name.append(i.text)         
        
time.sleep(2)
ex=driver.find_elements_by_xpath("//span[@class='a-price-whole']")
for i in ex:
    if i.text is None:
        Price.append('--')
    else:   
        Price.append(i.text)
 


time.sleep(2)
pr=driver.find_elements_by_xpath("//span[@class='a-price-whole']")
for i in pr:
    if i.text is None:
        Return_Exchange.append('--')
    else:   
        Return_Exchange.append(i.text)


# brand   
# titles=driver.find_elements_by_xpath("//span[@class='a-size-medium a-color-base a-text-normal']")
# for i in titles[:10]:
#     Title.append(i.text)

# %% [markdown]
# Q2 is incomplete will sove it later. facing some problem in it.

# %% [markdown]
# 3. Write a python program to access the search bar and search button on images.google.com and scrape 10
# images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
#fruits

Items=['fruits','cars','machine Learning','guitars','Cakes']

#launch browser
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
url='https://www.google.com/'
driver.get(url)
time.sleep(4)

#click on image icons
btn=driver.find_element_by_xpath("//a[text()='Images']")
btn.click()
search_box=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")

#search items
time.sleep(4)
search_box.clear()
search_box.send_keys('fruits')

c_btn=driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span")
c_btn.click()
time.sleep(4)

#creating blank list & add items into it.
fruits=[]

val=driver.find_elements_by_tag_name("img")

for i1 in val:
    fruits.append(i1.get_attribute('src'))
fruits=fruits[:10]

driver.close()

fruits
# Out:
# ['data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/png;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...']

# %%
#cars

#launch browser
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
url='https://www.google.com/'
driver.get(url)
time.sleep(4)

#click on image icons
btn=driver.find_element_by_xpath("//a[text()='Images']")
btn.click()
search_box=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")

#search items
time.sleep(4)
search_box.clear()
search_box.send_keys('cars')

c_btn=driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span")
c_btn.click()
time.sleep(4)

#creating blank list & add items into it.
cars=[]

val=driver.find_elements_by_tag_name("img")

for i1 in val:
    cars.append(i1.get_attribute('src'))
cars=cars[:10]

driver.close()

len(cars)
# Out:
# 10

# %%
#machine Learning

#launch browser
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
url='https://www.google.com/'
driver.get(url)
time.sleep(4)

#click on image icons
btn=driver.find_element_by_xpath("//a[text()='Images']")
btn.click()
search_box=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")

#search items
time.sleep(4)
search_box.clear()
search_box.send_keys('machine learning')

c_btn=driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span")
c_btn.click()
time.sleep(4)

#creating blank list & add items into it.
machine_Learning=[]

val=driver.find_elements_by_tag_name("img")

for i1 in val:
    machine_Learning.append(i1.get_attribute('src'))
machine_Learning=machine_Learning[:10]

driver.close()

len(machine_Learning)
# Out:
# 10

# %%
#guitars

#launch browser
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
url='https://www.google.com/'
driver.get(url)
time.sleep(4)

#click on image icons
btn=driver.find_element_by_xpath("//a[text()='Images']")
btn.click()
search_box=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")

#search items
time.sleep(4)
search_box.clear()
search_box.send_keys('guitars')

c_btn=driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span")
c_btn.click()
time.sleep(4)

#creating blank list & add items into it.
guitars=[]

val=driver.find_elements_by_tag_name("img")

for i1 in val:
    guitars.append(i1.get_attribute('src'))
guitars=guitars[:10]

driver.close()

len(guitars)
# Out:
# 10

# %%
#cakes

#launch browser
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
url='https://www.google.com/'
driver.get(url)
time.sleep(4)

#click on image icons
btn=driver.find_element_by_xpath("//a[text()='Images']")
btn.click()
search_box=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")

#search items
time.sleep(4)
search_box.clear()
search_box.send_keys('cakes')

c_btn=driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span")
c_btn.click()
time.sleep(4)

#creating blank list & add items into it.
cakes=[]

val=driver.find_elements_by_tag_name("img")

for i1 in val:
    cakes.append(i1.get_attribute('src'))
cakes=cakes[:10]

driver.close()

len(guitars)
# Out:
# 10

# %% [markdown]
# 4.Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your data in dataframe

# %%
#launch browser
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
url='https://www.flipkart.com/'
driver.get(url)
time.sleep(4)


driver.find_element_by_xpath("//input[@title='Search for products, brands and more']").send_keys('pixel 4a')
time.sleep(4)
btn=driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")
btn.click()
time.sleep(4)
btn=driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
btn.click()

#creating empty lists
Brand=[]
Smartphone_name=[]
Ram=[]
ROM=[]
Primary_camera=[]
Secondary_camera=[]
Display_size=[]
Battery_capacity=[]
Price=[]
URL=[]
time.sleep(8)
Brand=driver.find_element_by_xpath("//div[@class='_4rR01T']").text.split(' ')[0]
Smartphone_name=driver.find_element_by_xpath("//div[@class='_4rR01T']").text
Ram=driver.find_element_by_xpath("//ul[@class='_1xgFaf']/li[1]").text.split('|')[0]
ROM=driver.find_element_by_xpath("//ul[@class='_1xgFaf']/li[1]").text.split('|')[1]
Primary_camera=driver.find_element_by_xpath("//ul[@class='_1xgFaf']/li[3]").text.split('|')[0]
Secondary_camera=driver.find_element_by_xpath("//ul[@class='_1xgFaf']/li[3]").text.split('|')[1]
Display_size=driver.find_element_by_xpath("//ul[@class='_1xgFaf']/li[2]").text
Battery_capacity=driver.find_element_by_xpath("//ul[@class='_1xgFaf']/li[4]").text
Price=driver.find_element_by_xpath("//div[@class='_30jeq3 _1_WHN1']").text

urls = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
for i in urls:
    URL.append(i.get_attribute('href'))

URL=URL[0:1]

# %%
Mobile_df=pd.DataFrame({'Brand':Brand,
                        'Smartphone_name':Smartphone_name,
                        'Ram':Ram,
                        'ROM':ROM,
                        'Primary_camera':Primary_camera,
                        'Secondary_camera':Secondary_camera,
                        'Display_size':Display_size,
                        'Battery_capacity':Battery_capacity,
                        'Price':Price,
                        'URL':URL
    
})

Mobile_df
# Out:
#     Brand                       Smartphone_name        Ram          ROM  \
# 0  Google  Google Pixel 4a (Just Black, 128 GB)  6 GB RAM    128 GB ROM
#
#         Primary_camera   Secondary_camera  \
# 0  12.2MP Rear Camera    8MP Front Camera
#
#                             Display_size  Battery_capacity    Price  \
# 0  14.76 cm (5.81 inch) Full HD+ Display  3140 mAh Battery  ₹28,999
#
#                                                  URL
# 0  https://www.flipkart.com/google-pixel-4a-just-...

# %% [markdown]
# 5.Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps

# %%
city=str(input("Enter any city name to check latitude,longitude: "))
# Out:
# Enter any city name to check latitude,longitude: Ghazoabad

# %%
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
url='https://www.google.co.in/maps?hl=en'
driver.get(url)

# %%
#input city name
city=str(input("Enter any city name to check latitude,longitude: "))

#driver launch
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
url='https://www.google.co.in/maps?hl=en'
driver.get(url)
time.sleep(2)

#finy city name on path
driver.find_element_by_xpath("//input[@class='tactile-searchbox-input']").send_keys(city)

driver.find_element_by_xpath("//button[@class='nhb85d-BIqFsb']").send_keys(Keys.RETURN)
#scrapping url to get langitude/latitude
time.sleep(5)
page_url=driver.current_url

#splitting lat/long from page url

latitude=page_url.split('@')[1].split(',')[0]
longitude=page_url.split('@')[1].split(',')[1]

print('City:',city,'Latitude is:',latitude,'and Longitude is: ',longitude)
driver.close()
# Out:
# Enter any city name to check latitude,longitude: Delhi
# City: Delhi Latitude is: 28.6466772 and Longitude is:  76.8130673

# %% [markdown]
# 6.Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21) from trak.in.

# %%
#driver launch
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')
url='https://trak.in/india-startup-funding-investment-2015/'
driver.get(url)
time.sleep(4)

# %%
#fetching data for jan-21
Date=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-54 dataTable no-footer']/tbody/tr/td[2]")
for row in rows:
    Date.append(row.text)

Startup_name=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-54 dataTable no-footer']/tbody/tr/td[3]")
for row in rows:
    Startup_name.append(row.text)

  
Industry_vertical=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-54 dataTable no-footer']/tbody/tr/td[4]")
for row in rows:
    Industry_vertical.append(row.text)
    
    
    
sub_vertical=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-54 dataTable no-footer']/tbody/tr/td[5]")
for row in rows:
    sub_vertical.append(row.text)
    
    
City_location=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-54 dataTable no-footer']/tbody/tr/td[6]")
for row in rows:
    City_location.append(row.text)    
    
    
Investors_name=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-54 dataTable no-footer']/tbody/tr/td[7]")
for row in rows:
    Investors_name.append(row.text)    
    
Investors_type=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-54 dataTable no-footer']/tbody/tr/td[8]")
for row in rows:
    Investors_type.append(row.text)
    

Amount_usd=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-54 dataTable no-footer']/tbody/tr/td[9]")
for row in rows:
    Amount_usd.append(row.text)    
    
    
#Creating Dataframe

Jan_2021=pd.DataFrame({'Date':Date,
                       'Startup_name':Startup_name,
                       'Industry_vertical':Industry_vertical,
                       'sub_vertical':sub_vertical,
                       'City_location':City_location,
                       'Investors_name':Investors_name,
                       'Investors_type':Investors_type,
                       'Amount_usd':Amount_usd,
                       })

Jan_2021
# Out:
#          Date            Startup_name       Industry_vertical  \
# 0  15/01/2021         Digit Insurance      Financial Services
# 1  28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 2  19/01/2021                  DeHaat        AgriTech Startup
# 3  19/01/2021               Darwinbox                    SaaS
# 4  18/01/2021                   mfine     Health Tech Startup
# 5  18/01/2021                   Udayy                  EdTech
# 6  11/01/2021           True Elements            Food Startup
# 7  13/01/2021                   Saveo          B2B E-commerce
#
#                                         sub_vertical City_location  \
# 0                                 Insurance Services     Bengaluru
# 1      Shave care, beard care, and skincare products     New Delhi
# 2  online marketplace for farm products and services         Patna
# 3                                            HR Tech        Mumbai
# 4                 AI-powered telemedicine mobile app     Bengaluru
# ...

# %%
#fetching data for Feb-21
Date=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-55 dataTable no-footer']/tbody/tr/td[2]")
for row in rows:
    Date.append(row.text)

Startup_name=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-55 dataTable no-footer']/tbody/tr/td[3]")
for row in rows:
    Startup_name.append(row.text)

  
Industry_vertical=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-55 dataTable no-footer']/tbody/tr/td[4]")
for row in rows:
    Industry_vertical.append(row.text)
    
    
    
sub_vertical=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-55 dataTable no-footer']/tbody/tr/td[5]")
for row in rows:
    sub_vertical.append(row.text)
    
    
City_location=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-55 dataTable no-footer']/tbody/tr/td[6]")
for row in rows:
    City_location.append(row.text)    
    
    
Investors_name=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-55 dataTable no-footer']/tbody/tr/td[7]")
for row in rows:
    Investors_name.append(row.text)    
    
Investors_type=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-55 dataTable no-footer']/tbody/tr/td[8]")
for row in rows:
    Investors_type.append(row.text)
    

Amount_usd=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-55 dataTable no-footer']/tbody/tr/td[9]")
for row in rows:
    Amount_usd.append(row.text)    
    
    
#Creating Dataframe

Feb_2021=pd.DataFrame({'Date':Date,
                       'Startup_name':Startup_name,
                       'Industry_vertical':Industry_vertical,
                       'sub_vertical':sub_vertical,
                       'City_location':City_location,
                       'Investors_name':Investors_name,
                       'Investors_type':Investors_type,
                       'Amount_usd':Amount_usd,
                       })

Feb_2021
# Out:
#          Date Startup_name Industry_vertical                   sub_vertical  \
# 0  11/02/2021     Doubtnut          Edu Tech            E-Learning Platform
# 1  22/02/2021       Zomato       Hospitality  Online Food Delivery Platform
# 2  19/02/2021    Fingerlix       Hospitality  Semi-cooked food delivery app
# 3  17/02/2021        Zolve           FinTech         Global Neobank Venture
# 4  15/02/2021    KreditBee           Finance       Digital lending platform
# 5  12/02/2021    Pepperfry        E-commerce    Multi-brand furniture brand
# 6  12/02/2021      Grofers        E-Commerce             Online supermarket
# 7  09/02/2021      Nothing        Technology    Consumer Technology Venture
# 8  09/02/2021  SplashLearn            EdTech  Game-based learning programme
#
#   City_location                                     Investors_name  \
# 0       Gurgaon  SIG Global, Sequoia Capital, WaterBridge Ventu...
# 1       Gurgaon                                 Tiger Global, Kora
# ...

# %%
#fetching data for Mar-21
Date=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-56 dataTable no-footer']/tbody/tr/td[2]")
for row in rows:
    Date.append(row.text)

Startup_name=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-56 dataTable no-footer']/tbody/tr/td[3]")
for row in rows:
    Startup_name.append(row.text)

  
Industry_vertical=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-56 dataTable no-footer']/tbody/tr/td[4]")
for row in rows:
    Industry_vertical.append(row.text)
    
    
    
sub_vertical=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-56 dataTable no-footer']/tbody/tr/td[5]")
for row in rows:
    sub_vertical.append(row.text)
    
    
City_location=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-56 dataTable no-footer']/tbody/tr/td[6]")
for row in rows:
    City_location.append(row.text)    
    
    
Investors_name=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-56 dataTable no-footer']/tbody/tr/td[7]")
for row in rows:
    Investors_name.append(row.text)    
    
Investors_type=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-56 dataTable no-footer']/tbody/tr/td[8]")
for row in rows:
    Investors_type.append(row.text)
    

Amount_usd=[]
rows=driver.find_elements_by_xpath("//table[@class='tablepress tablepress-id-56 dataTable no-footer']/tbody/tr/td[9]")
for row in rows:
    Amount_usd.append(row.text)    
    
    
#Creating Dataframe

Mar_2021=pd.DataFrame({'Date':Date,
                       'Startup_name':Startup_name,
                       'Industry_vertical':Industry_vertical,
                       'sub_vertical':sub_vertical,
                       'City_location':City_location,
                       'Investors_name':Investors_name,
                       'Investors_type':Investors_type,
                       'Amount_usd':Amount_usd,
                       })

Mar_2021
# Out:
#          Date Startup_name Industry_vertical  \
# 0  04/03/2021    DealShare        E-commerce
# 1  31/03/2021     Uniphore        Technology
# 2  30/03/2021        Dunzo        E-commerce
# 3  30/03/2021       BYJU’S          Edu-tech
# 4  23/03/2021  SkilloVilla          Edu-tech
# 5  25/03/2021     CityMall        E-commerce
# 6  26/03/2021        DotPe           FinTech
#
#                                         sub_vertical      City_location  \
# 0                           Online shopping platform  Jaipur, Rajasthan
# 1            Conversational Service Automation (CSA)          Palo Alto
# 2                           Hyper-local delivery app          Bengaluru
# 3                                    Online tutoring          Bengaluru
# 4                Career and job-oriented upskilling.          Bengaluru
# 5       Social ecommerce and online grocery platform            Gurgaon
# 6  Commerce and payments platform to offline ente...            Gurgaon
#
# ...

# %% [markdown]
# 7.Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')

driver.get('https://www.digit.in/top-products/best-gaming-laptops-40.html')

laptop_name=[]
OS=[]
Display=[]
Processor=[]
Memory=[]
Weight=[]
Dimension=[]
GraphicsProcessor=[]

# %%
name=driver.find_elements_by_tag_name("h3")
for i in name:
    laptop_name.append(i.text)
    
    
os=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[3]/td[3]")
for i in os:
    OS.append(i.text)    
 
disp=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[4]/td[3]")
for i in disp:
    Display.append(i.text)
    
pro=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[5]/td[3]")
for i in pro:
    Processor.append(i.text)
    
mem=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[6]/td[3]")
for i in mem:
    Memory.append(i.text)
  
wei=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[7]/td[3]")
for i in wei:
    Weight.append(i.text)
    
    
dim=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[8]/td[3]")
for i in dim:
    Dimension.append(i.text)    
    

gaming_laptop_df=pd.DataFrame({'laptop_name':laptop_name,
'OS':OS,
'Display':Display,
'Processor':Processor,
'Memory':Memory,
'Weight':Weight,
'Dimension':Dimension
})

gaming_laptop_df
# Out:
#                                      laptop_name               OS  \
# 0                    ACER NITRO 5 RYZEN 9 (2021)       Windows 10
# 1  MSI STEALTH 15M 11TH GEN CORE I7-11375H (2021       Windows 10
# 2   ASUS ROG STRIX SCAR 15 RYZEN 9-5900HX (2021)       Windows 10
# 3                          ALIENWARE AREA 51M R2  Windows 10 Home
# 4                               ALIENWARE M15 R3  Windows 10 Home
# 5                         ASUS ROG STRIX SCAR 15  Windows 10 Home
# 6                          ASUS ROG ZEPHYRUS G14  Windows 10 Home
# 7                               LENOVO LEGION 5I   Windows 10 Pro
# 8                       ASUS ROG ZEPHYRUS DUO 15       Windows 10
# 9                           ACER ASPIRE 7 GAMING  Windows 10 Home
#
#                Display                                   Processor  \
# 0  15.6" (1920 x 1080)             AMD Ryzen 9 Octa Core | 2.4 GHz
# 1  15.6" (1920 x 1080)        Intel Core i7 11th Gen - 11375H | NA
# ...

# %% [markdown]
# 8.Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')

driver.get('https://www.forbes.com/billionaires/')

time.sleep(8)
Rank=[]
Name=[]
Net_worth=[]
Age=[]
Citizenship=[]
Source=[]
Industry=[]


rk=driver.find_elements_by_xpath("//div[@class='rank']")
for i in rk:
    Rank.append(i.text)
    
 
nm=driver.find_elements_by_xpath("//div[@class='personName']")
for i in nm:
    Name.append(i.text)
    
net=driver.find_elements_by_xpath("//div[@class='netWorth']")
for i in net:
    Net_worth.append(i.text)
    
    
ag=driver.find_elements_by_xpath("//div[@class='age']")
for i in ag:
    Age.append(i.text)
    
cntry=driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
for i in cntry:
    Citizenship.append(i.text)
    
srce=driver.find_elements_by_xpath("//div[@class='source-column']")
for i in srce:
    Source.append(i.text)
    
    
indus=driver.find_elements_by_xpath("//div[@class='category']")
for i in indus:
    Industry.append(i.text)
    
print(len(Rank),len(Name),len(Net_worth),len(Age),len(Citizenship),len(Source),len(Industry))  



billionaires=pd.DataFrame({'Rank':Rank,
'Name':Name,
'Net_worth':Net_worth,
'Age':Age,
'Citizenship':Citizenship,
'Source':Source,
'Industry':Industry
})                          
                           
billionaires
# Out:
# 200 200 200 200 200 200 200
#      Rank                      Name Net_worth Age    Citizenship  \
# 0      1.                Jeff Bezos    $177 B  57  United States
# 1      2.                 Elon Musk    $151 B  49  United States
# 2      3.  Bernard Arnault & family    $150 B  72         France
# 3      4.                Bill Gates    $124 B  65  United States
# 4      5.           Mark Zuckerberg     $97 B  36  United States
# ..    ...                       ...       ...  ..            ...
# 195  195.           Harry Triguboff   $11.2 B  88      Australia
# 196  197.     Leonid Fedun & family   $11.1 B  65         Russia
# 197  197.                 Eyal Ofer   $11.1 B  70         Israel
# 198  197.              Evan Spiegel   $11.1 B  30  United States
# 199  200.     Luis Carlos Sarmiento     $11 B  88       Colombia
#
#                     Source               Industry
# 0                   Amazon             Technology
# 1            Tesla, SpaceX             Automotive
# ...

# %% [markdown]
# 9.Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
driver=webdriver.Chrome(r'C:/Users/91995/Downloads/chromedriver_win32/chromedriver.exe')

driver.get('https://www.youtube.com/watch?v=csP2Qr3f_bg')

time.sleep(10)

Comment=[]
posted_time=[]

# %%
cmt=driver.find_elements_by_id("content-text")

for i in cmt:
    Comment.append(i.text)

time=driver.find_elements_by_xpath("//a[@class='yt-simple-endpoint style-scope yt-formatted-string']")
for i in time:
    posted_time.append(i.text)

# %%
posted_time=posted_time[2:45:2]

# %%
cmt_df=pd.DataFrame({'Comment':Comment,
                     'posted_time':posted_time
                     
                    })

# %%
cmt_df
# Out:
#                                               Comment   posted_time
# 0                            I enjoy these so much 😍😍  2 months ago
# 1   "Yesterday is a history "\n"Tomorrow is a myst...   10 days ago
# 2                                        Beautiful 🔥🔥   1 month ago
# 3                                                Nice    3 days ago
# 4   "Yesterday is a history " \n"Tomorrow is a mys...    6 days ago
# 5                                                 Wow    3 days ago
# 6   Please someone call triggered insaan to roast ...    2 days ago
# 7                                           Beautiful   2 weeks ago
# 8                                       Beautiful❤️❤️    5 days ago
# 9                                           Very nice    4 days ago
# 10  "Yesterday is a history "\n"Tomorrow is a myst...   10 days ago
# 11                                               Haha   10 days ago
# 12                                             Nice😉😘  2 months ago
# ...
